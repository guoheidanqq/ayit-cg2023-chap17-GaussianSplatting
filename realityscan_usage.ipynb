# %% [markdown]
# # step 1
# 拍摄图片
# 处理图片
# 重命名图片
# 图片要缩小，保持比例的缩小

# %% [markdown]
# # step 2
# align images
# 双击重新设定原点，旋转平面，使得物体的建模中心和世界中心重合
# # step 3
#
#
# # step 4
# calculate model
# # step 5
# unwrap
# texture & colorize

# %%
quick key: numpad  1  3d view  2 3 4 5  6 7  quad view

# %% [markdown]
# # Realityscan output fbx
# * 在导出的时候不要选择相机，不要导出拍摄的图片，会导致导出的fbx文件过大。
# * 在导出fbx的时候一定要选择渲染好的纹理，而不是Checkbox纹理测试图，
# * maya2025不稳定，老是死机，应该使用maya2020版本，应该使用 Mesh-> Reduce  to 50%, then check if ok ,
# * Mesh->cleanup to remove no topo faces
# * Mesh->reduce to 50%

# %% [markdown]
# # realityscan usage
# import images to
# align images
# set ground plane
# tools->set ground plane   to adjust model align to world plane
# tools ->set reconstruction origin  to adjust model align to world origin
#
# in set ground plane mode, double click on a point to set origin of model

# %% [markdown]
# #  maya tranfer normal map
# * in Rendering workspace
# * Modify → Freeze Transformations
# * Edit → Delete by Type → History
#
# * Rendering → Lighting/Shading → Transfer Maps
# * use png  4k
# * target is low poly mesh
# * source is high poly mesh
#
# * normal map Space: Tangent Space，else is Object Space
