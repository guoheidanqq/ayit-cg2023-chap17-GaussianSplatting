# %% [markdown]
# # step 1
# 拍摄图片
# 处理图片
# 重命名图片
# 图片要缩小，保持比例的缩小

# %% [markdown]
# # step 2
# align images
# 双击重新设定原点，旋转平面，使得物体的建模中心和世界中心重合
# # step 3
#
#
# # step 4
# calculate model
# # step 5
# unwrap
# texture & colorize

# %%
quick key: numpad  1  3d view  2 3 4 5  6 7  quad view

# %% [markdown]
# # realityscan usage
# import images to
# align images
# set ground plane
# tools->set ground plane   to adjust model align to world plane
# tools ->set reconstruction origin  to adjust model align to world origin
#
# in set ground plane mode, double click on a point to set origin of model
